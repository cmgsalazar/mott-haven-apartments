# %% [markdown]
# ## MNS rental market reports
#
# In this notebook, we will be downloading monthly and year-end rental market reports for Bronx from [MNS](https://www.mns.com/bronx_rental_market_report). The files are in PDF format.

# %%
# importing libraries
from bs4 import BeautifulSoup
import requests
import pandas as pd
import os
import wget
from random import randrange
import time

# %%
# requesting URL
url = "https://www.mns.com/bronx_rental_market_report"
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
# soupifying HTML
soup = BeautifulSoup(response.text, "html.parser")

# %% [markdown]
# ### Scraping, saving links to a `csv`

# %%
# getting all the links we want
# checking the source code, we find that they're all under the <select> tag with id="report_month"
# target_links = soup.find_all("select", id="report_month")

# but, we also saw that only the links we need are under the <option> tag
target_links = soup.find_all("option")
target_links
# Out:
# [<option value="select">Select report month</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_sep_24.pdf">September 2024</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_aug_24.pdf">August 2024</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_jul_24.pdf">July 2024</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_jun_24.pdf">June 2024</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_may_24.pdf">May 2024</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_apr_24.pdf">April 2024</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_mar_24.pdf">March 2024</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_feb_24.pdf">February 2024</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_jan_24.pdf">January 2024</option>,
#  <option value="http://www.mns.com/pdf/bronx_year_end_market_report_2023.pdf">Year End 2023</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_dec_23.pdf">December 2023</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_nov_23.pdf">November 2023</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_oct_23.pdf">October 2023</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_sep_23.pdf">September 2023</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_aug_23.pdf">August 2023</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_jul_23.pdf">July 2023</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_jun_23.pdf">June 2023</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_may_23.pdf">May 2023</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_apr_23.pdf">April 2023</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_mar_23.pdf">March 2023</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_feb_23.pdf">February 2023</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_jan_23.pdf">January 2023</option>,
#  <option value="http://www.mns.com/pdf/bronx_year_end_market_report_2022.pdf">Year End 2022</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_dec_22.pdf">December 2022</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_nov_22.pdf">November 2022</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_oct_22.pdf">October 2022</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_sep_22.pdf">September 2022</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_aug_22.pdf">August 2022</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_jul_22.pdf">July 2022</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_jun_22.pdf">June 2022</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_may_22.pdf">May 2022</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_apr_22.pdf">April 2022</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_mar_22.pdf">March 2022</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_feb_22.pdf">February 2022</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_jan_22.pdf">January 2022</option>,
#  <option value="http://www.mns.com/pdf/bronx_year_end_market_report_2021.pdf">Year End 2021</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_dec_21.pdf">December 2021</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_nov_21.pdf">November 2021</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_oct_21.pdf">October 2021</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_sep_21.pdf">September 2021</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_aug_21.pdf">August 2021</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_jul_21.pdf">July 2021</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_jun_21.pdf">June 2021</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_may_21.pdf">May 2021</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_apr_21.pdf">April 2021</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_mar_21.pdf">March 2021</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_feb_21.pdf">February 2021</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_jan_21.pdf">January 2021</option>,
#  <option value="http://www.mns.com/pdf/bronx_year_end_market_report_2020.pdf">Year End 2020</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_dec_20.pdf">December 2020</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_nov_20.pdf">November 2020</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_oct_20.pdf">October 2020</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_sep_20.pdf">September 2020</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_aug_20.pdf">August 2020</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_jul_20.pdf">July 2020</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_jun_20.pdf">June 2020</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_may_20.pdf">May 2020</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_apr_20.pdf">April 2020</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_mar_20.pdf">March 2020</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_feb_20.pdf">February 2020</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_jan_20.pdf">January 2020</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_dec_19.pdf">December 2019</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_nov_19.pdf">November 2019</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_oct_19.pdf">October 2019</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_sep_19.pdf">September 2019</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_aug_19.pdf">August 2019</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_jul_19.pdf">July 2019</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_jun_19.pdf">June 2019</option>,
#  <option value="http://www.mns.com/pdf/bronx_market_report_may_19.pdf">May 2019</option>]

# %%
# we don't need the first item on the list
# so we're updating the list by slicing it
target_links = target_links[1:]

# %%
# getting only the links, which are inside the "value" attribute
# we're making two datasets: monthly reports and yearend reports

monthly_reports = [] # will hold our download links for monthly reports
monthly_list = [] # will hold our download links for monthly reports
yearend_reports = [] # will hold our download links for yearend reports
yearend_list = [] # will hold our download links for yearend reports

for link in target_links:
    if "Year End" in link.text:
        yearend_reports.append(link["value"])
        yearend_list.append(link.text)
    else:
        monthly_reports.append(link["value"])
        monthly_list.append(link.text)
print("Done!")
# Out:
# Done!

# %%
# printing to check if it worked
print(yearend_reports[0:2])
print(yearend_list[0:2])
print(monthly_reports[0:2])
print(monthly_list[0:2])
# Out:
# ['http://www.mns.com/pdf/bronx_year_end_market_report_2023.pdf', 'http://www.mns.com/pdf/bronx_year_end_market_report_2022.pdf']
# ['Year End 2023', 'Year End 2022']
# ['http://www.mns.com/pdf/bronx_market_report_sep_24.pdf', 'http://www.mns.com/pdf/bronx_market_report_aug_24.pdf']
# ['September 2024', 'August 2024']

# %%
# saving the yearend reports into df, then csv for safekeeping

yearend_data = [ {"period": year, "link": link} for (year, link) in zip(yearend_list, yearend_reports) ]
bx_yearend = pd.DataFrame(yearend_data)
bx_yearend.to_csv("bx_yearend_reports.csv", encoding="UTF-8", index=False)

# %%
# saving the monthly reports into df, then csv for safekeeping

monthly_data = [ {"period": year, "link": link} for (year, link) in zip(monthly_list, monthly_reports) ]
bx_monthly = pd.DataFrame(monthly_data)
bx_monthly.to_csv("bx_monthly_reports.csv", encoding="UTF-8", index=False)

# %% [markdown]
# ### Defining functions to make downloading easier for us

# %%
# downloading the files

def downloader(links_list, folder_name):
    '''
    This function downloads each of the files in a list of links and saves it to the folder identified. 
    It requires `import os` to run.
    Initialize `counter = 0` and `errors_list = []` before running function.
    
    Parameters:
    links_list(list) = list of URLs for download
    folder_name (str) = name of folder where files will be saved; this will be created if it does not exist
    '''
    os.makedirs(folder_name, exist_ok=True)

    print(f"Downloading link {counter} of {len(links_list)}...")
    try:
        wget.download(item, out=folder_name)
    except Exception as e:
        errors_list.append((item, e))
        print(f"Something went wrong with link {counter} due to {e}.")

# %%
# snoozer

def snoozer(start_time, end_time):
    '''
    This function creates a snoozer that can be used when scraping.
    It requires `from random import randrange` and `import time`. 
    
    Parameters: 
    start_time (int) = start time of range, in seconds
    end_time (int) = end time of range, in seconds
    '''
    timer = randrange(start_time, end_time)
    print("") # adds a line break for readability
    print(f"Snoozing for {timer} seconds...")
    time.sleep(timer)

# %% [markdown]
# ### Now, the downloading actually happens!

# %%
# downloading actual PDFs of yearend reports

counter = 0
errors_list = []

for item in yearend_reports:
    counter += 1
    downloader(yearend_reports, "yearend-reports")
    if counter <= len(yearend_reports) - 1: # so it does not snooze when the downloads are all done
        snoozer(12, 34)
    print("") # adds a line break per item downloaded    
print("Downloads done!")
# Out:
# Downloading link 1 of 4...
# 100% [......................................................] 7731223 / 7731223
# Snoozing for 22 seconds...
#
# Downloading link 2 of 4...
# 100% [......................................................] 7724989 / 7724989
# Snoozing for 14 seconds...
#
# Downloading link 3 of 4...
# 100% [......................................................] 7721986 / 7721986
# Snoozing for 32 seconds...
#
# Downloading link 4 of 4...
# 100% [......................................................] 8759323 / 8759323
# Downloads done!

# %%
# downloading actual PDFs of monthly reports

counter = 0
errors_list = []

for item in monthly_reports:
    counter += 1
    downloader(monthly_reports, "monthly-reports")
    if counter <= len(monthly_reports) - 1: # so it does not snooze when the downloads are all done
        snoozer(12, 34)
    print("") # adds a line break per item downloaded   
print("Downloads done!")
# Out:
# Downloading link 1 of 65...
# 100% [......................................................] 6110141 / 6110141
# Snoozing for 21 seconds...
#
# Downloading link 2 of 65...
# 100% [......................................................] 6073250 / 6073250
# Snoozing for 29 seconds...
#
# Downloading link 3 of 65...
# 100% [......................................................] 5987964 / 5987964
# Snoozing for 28 seconds...
#
# Downloading link 4 of 65...
# 100% [......................................................] 5990148 / 5990148
# Snoozing for 22 seconds...
#
# Downloading link 5 of 65...
# 100% [......................................................] 5933668 / 5933668
# Snoozing for 24 seconds...
#
# Downloading link 6 of 65...
# 100% [......................................................] 5951542 / 5951542
# Snoozing for 18 seconds...
#
# Downloading link 7 of 65...
# 100% [......................................................] 5993589 / 5993589
# Snoozing for 16 seconds...
#
# Downloading link 8 of 65...
# 100% [......................................................] 5966708 / 5966708
# Snoozing for 30 seconds...
#
# Downloading link 9 of 65...
# 100% [......................................................] 5975549 / 5975549
# Snoozing for 12 seconds...
#
# Downloading link 10 of 65...
# 100% [......................................................] 5970441 / 5970441
# Snoozing for 13 seconds...
#
# Downloading link 11 of 65...
# 100% [......................................................] 5966433 / 5966433
# Snoozing for 12 seconds...
#
# Downloading link 12 of 65...
# 100% [......................................................] 6007975 / 6007975
# Snoozing for 24 seconds...
#
# Downloading link 13 of 65...
# 100% [......................................................] 5946156 / 5946156
# Snoozing for 23 seconds...
#
# Downloading link 14 of 65...
# 100% [......................................................] 5992413 / 5992413
# Snoozing for 31 seconds...
#
# Downloading link 15 of 65...
# 100% [......................................................] 6011281 / 6011281
# Snoozing for 26 seconds...
#
# Downloading link 16 of 65...
# 100% [......................................................] 6007060 / 6007060
# Snoozing for 29 seconds...
#
# Downloading link 17 of 65...
# 100% [......................................................] 6005589 / 6005589
# Snoozing for 24 seconds...
#
# Downloading link 18 of 65...
# 100% [......................................................] 5996533 / 5996533
# Snoozing for 30 seconds...
#
# Downloading link 19 of 65...
# 100% [......................................................] 5960368 / 5960368
# Snoozing for 32 seconds...
#
# Downloading link 20 of 65...
# 100% [......................................................] 5940938 / 5940938
# Snoozing for 31 seconds...
#
# Downloading link 21 of 65...
# 100% [......................................................] 5943870 / 5943870
# Snoozing for 29 seconds...
#
# Downloading link 22 of 65...
# 100% [........................................................] 859424 / 859424
# Snoozing for 19 seconds...
#
# Downloading link 23 of 65...
# 100% [......................................................] 5940580 / 5940580
# Snoozing for 15 seconds...
#
# Downloading link 24 of 65...
# 100% [......................................................] 5960645 / 5960645
# Snoozing for 21 seconds...
#
# Downloading link 25 of 65...
# 100% [......................................................] 5935390 / 5935390
# Snoozing for 25 seconds...
#
# Downloading link 26 of 65...
# 100% [......................................................] 6012866 / 6012866
# Snoozing for 25 seconds...
#
# Downloading link 27 of 65...
# 100% [......................................................] 6044570 / 6044570
# Snoozing for 23 seconds...
#
# Downloading link 28 of 65...
# 100% [......................................................] 6042532 / 6042532
# Snoozing for 23 seconds...
#
# Downloading link 29 of 65...
# 100% [......................................................] 5102064 / 5102064
# Snoozing for 23 seconds...
#
# Downloading link 30 of 65...
# 100% [......................................................] 5982506 / 5982506
# Snoozing for 25 seconds...
#
# Downloading link 31 of 65...
# 100% [......................................................] 5981893 / 5981893
# Snoozing for 27 seconds...
#
# Downloading link 32 of 65...
# 100% [......................................................] 5946391 / 5946391
# Snoozing for 22 seconds...
#
# Downloading link 33 of 65...
# 100% [......................................................] 5955086 / 5955086
# Snoozing for 15 seconds...
#
# Downloading link 34 of 65...
# 100% [........................................................] 571327 / 571327
# Snoozing for 24 seconds...
#
# Downloading link 35 of 65...
# 100% [......................................................] 1816363 / 1816363
# Snoozing for 16 seconds...
#
# Downloading link 36 of 65...
# 100% [......................................................] 6352356 / 6352356
# Snoozing for 13 seconds...
#
# Downloading link 37 of 65...
# 100% [......................................................] 6410777 / 6410777
# Snoozing for 28 seconds...
#
# Downloading link 38 of 65...
# 100% [......................................................] 6290912 / 6290912
# Snoozing for 24 seconds...
#
# Downloading link 39 of 65...
# 100% [......................................................] 6237768 / 6237768
# Snoozing for 32 seconds...
#
# Downloading link 40 of 65...
# 100% [......................................................] 6230461 / 6230461
# Snoozing for 18 seconds...
#
# Downloading link 41 of 65...
# 100% [......................................................] 6250596 / 6250596
# Snoozing for 28 seconds...
#
# Downloading link 42 of 65...
# 100% [......................................................] 6253473 / 6253473
# Snoozing for 14 seconds...
#
# Downloading link 43 of 65...
# 100% [......................................................] 6301192 / 6301192
# Snoozing for 21 seconds...
#
# Downloading link 44 of 65...
# 100% [......................................................] 6390398 / 6390398
# Snoozing for 30 seconds...
#
# Downloading link 45 of 65...
# 100% [......................................................] 6329207 / 6329207
# Snoozing for 21 seconds...
#
# Downloading link 46 of 65...
# 100% [......................................................] 6398157 / 6398157
# Snoozing for 27 seconds...
#
# Downloading link 47 of 65...
# 100% [......................................................] 6401762 / 6401762
# Snoozing for 30 seconds...
#
# Downloading link 48 of 65...
# 100% [......................................................] 6360971 / 6360971
# Snoozing for 14 seconds...
#
# Downloading link 49 of 65...
# 100% [......................................................] 6466399 / 6466399
# Snoozing for 14 seconds...
#
# Downloading link 50 of 65...
# 100% [......................................................] 6326533 / 6326533
# Snoozing for 14 seconds...
#
# Downloading link 51 of 65...
# 100% [......................................................] 6274611 / 6274611
# Snoozing for 27 seconds...
#
# Downloading link 52 of 65...
# 100% [......................................................] 6266466 / 6266466
# Snoozing for 20 seconds...
#
# Downloading link 53 of 65...
# 100% [......................................................] 6272146 / 6272146
# Snoozing for 21 seconds...
#
# Downloading link 54 of 65...
# 100% [........................................................] 868527 / 868527
# Snoozing for 32 seconds...
#
# Downloading link 55 of 65...
# 100% [........................................................] 867632 / 867632
# Snoozing for 26 seconds...
#
# Downloading link 56 of 65...
# 100% [........................................................] 738050 / 738050
# Snoozing for 28 seconds...
#
# Downloading link 57 of 65...
# 100% [......................................................] 6048961 / 6048961
# Snoozing for 19 seconds...
#
# Downloading link 58 of 65...
# 100% [........................................................] 562303 / 562303
# Snoozing for 21 seconds...
#
# Downloading link 59 of 65...
# 100% [......................................................] 1318250 / 1318250
# Snoozing for 19 seconds...
#
# Downloading link 60 of 65...
# 100% [......................................................] 6421774 / 6421774
# Snoozing for 24 seconds...
#
# Downloading link 61 of 65...
# 100% [......................................................] 6654356 / 6654356
# Snoozing for 26 seconds...
#
# Downloading link 62 of 65...
# 100% [........................................................] 434277 / 434277
# Snoozing for 14 seconds...
#
# Downloading link 63 of 65...
# 100% [........................................................] 433035 / 433035
# Snoozing for 30 seconds...
#
# Downloading link 64 of 65...
# 100% [........................................................] 432698 / 432698
# Snoozing for 25 seconds...
#
# Downloading link 65 of 65...
# 100% [........................................................] 432289 / 432289
# Downloads done!

# %% [markdown]
# #### Longer version of the code that I used a basis for my functions:

# %%
# # downloading actual PDFs of yearend reports

# # creating a new folder to hold our yearend reports
# downloads_folder = "yearend-reports"
# os.makedirs(downloads_folder, exist_ok=True)

# # other variables we need
# counter = 0
# errors_list = [] # will hold any problematic link
# start_range, end_range = 12, 31

# # downloading
# for report in yearend_reports:
#     counter += 1
#     print(f"Downloading link {counter} of {len(yearend_reports)}")
#     try:
#         wget.download(report, out=downloads_folder)
#     except Exception as e:
#         errors_list.append((report, e))
#         print(f"Something went wrong in link {counter} due to {e}.")
#     snoozer(start_range, end_range)
# print("Downloads done!")
