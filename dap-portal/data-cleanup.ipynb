# %% [markdown]
# # DAP Portal
#
# The [Displacement Alert Project (DAP) Portal](https://portal.displacementalert.org/district-dashboard/zipcode/10454) collates information about New York City neighborhoods' housing landscape. For this project, we are targetting only a specific community in the South Bronx that we are identifying under zip code 10454 — further filtering this down to only waterfront apartments.

# %%
# import libraries
import pandas as pd

# %%
# read csv

df = pd.read_csv("residential_properties__zipcode10454__12_02_2021-12_09_2024.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1141 entries, 0 to 1140
# Data columns (total 19 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   BBL                                                      1141 non-null   int64
#  1   Address                                                  1141 non-null   object
#  2   Zip Code                                                 1141 non-null   int64
#  3   Year Built                                               1141 non-null   int64
#  4   Total Units                                              1141 non-null   int64
#  5   Residential Units                                        1141 non-null   int64
#  6   Rent Stabilized Units                                    1141 non-null   int64
#  7   Latest sale price                                        1141 non-null   int64
# ...

# %%
# from https://propertyinformationportal.nyc.gov/

blocks_list = [
    "202319", "202317", "202316", "202309", "202308", "202295", "202296", "202278", "202277", "202261", "202260", "202562", "202546"
]

# %%
filtered_df = pd.DataFrame()

for block in blocks_list:
    new_df = df[df["BBL"]
    .astype(str)
    .str
    .startswith(block)
    ]

    filtered_df = pd.concat([filtered_df, new_df], ignore_index=True)

# %%
len(filtered_df)
# Out:
# 137

# %%
filtered_df
# Out:
#             BBL                Address  Zip Code  Year Built  Total Units  \
# 0    2023170015     129 Lincoln Avenue     10454        1928            2
# 1    2023170013     133 Lincoln Avenue     10454        1940            4
# 2    2023170043     143 Lincoln Avenue     10454        1910           31
# 3    2023160001     101 Lincoln Avenue     10454        2020          926
# 4    2023097502   135 Alexander Avenue     10454        2015            7
# ..          ...                    ...       ...         ...          ...
# 132  2025460097  580 East 134th Street     10454        1910            2
# 133  2025460096  578 East 134th Street     10454        1920            4
# 134  2025460140  124 Saint Anns Avenue     10454        1915           17
# 135  2025460094  574 East 134th Street     10454        1910            1
# 136  2025460095  576 East 134th Street     10454        1910            2
#
#      Residential Units  Rent Stabilized Units  Latest sale price  \
# ...

# %%
filtered_df.to_csv("filtered-properties.csv", encoding="UTF-8", index=False)
